# %%
# !pip3 install matplotlib pandas
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('~/Desktop/LSMTProject/results/mongodb/mongodb-readAndModify-pidstat.csv')
df
# Out:
#     %usr  %system  %guest  %wait  %CPU  CPU  minflt/s  majflt/s     VSZ  \
# 0   23.0      4.0     0.0    0.0  27.0    1    5924.0       0.0  309652
# 1    7.0      1.0     0.0    0.0   8.0    0       1.0       0.0  309652
# 2    7.0      0.0     0.0    0.0   7.0    1       0.0       0.0  309652
# 3    5.0      1.0     0.0    0.0   6.0    0       0.0       0.0  309652
# 4    6.0      0.0     0.0    0.0   6.0    1       0.0       0.0  309652
# ..   ...      ...     ...    ...   ...  ...       ...       ...     ...
# 70   5.0      1.0     0.0    0.0   6.0    0       0.0       0.0  309652
# 71   5.0      0.0     0.0    0.0   5.0    0       0.0       0.0  309652
# 72   6.0      0.0     0.0    0.0   6.0    0       0.0       0.0  309652
# 73   5.0      1.0     0.0    0.0   6.0    0       0.0       0.0  309652
# 74   4.0      0.0     0.0    0.0   4.0    1      10.0       0.0  309652
#
#       RSS  %MEM  StkSize  StkRef  kB_rd/s  kB_wr/s  kB_ccwr/s  iodelay  \
# 0   23160  0.28      132      84      0.0      0.0        0.0        0
# 1   23160  0.28      132      84      0.0      0.0        0.0        0
# 2   23160  0.28      132      84      0.0      0.0        0.0        0
# 3   23160  0.28      132      84      0.0      0.0        0.0        0
# 4   23160  0.28      132      84      0.0      0.0        0.0        0
# ..    ...   ...      ...     ...      ...      ...        ...      ...
# 70  23160  0.28      132      84      0.0      0.0        0.0        0
# 71  23160  0.28      132      84      0.0      0.0        0.0        0
# 72  23160  0.28      132      84      0.0      0.0        0.0        0
# 73  23160  0.28      132      84      0.0      0.0        0.0        0
# 74  23160  0.28      132      84      0.0      0.0        0.0        0
#
#                  Workload
# 0   mongodb-readAndModify
# 1   mongodb-readAndModify
# 2   mongodb-readAndModify
# 3   mongodb-readAndModify
# 4   mongodb-readAndModify
# ..                    ...
# 70  mongodb-readAndModify
# 71  mongodb-readAndModify
# 72  mongodb-readAndModify
# 73  mongodb-readAndModify
# 74  mongodb-readAndModify
#
# [75 rows x 18 columns]

# %%
useless = ["CPU", "Workload"]
workload = df["Workload"][0]
for i in df.columns:
    if(i not in useless):
        plt.plot(df[i], label=i)
        plt.legend()
        plt.savefig(workload + "-" + i.replace("/", "-") + ".png")
        plt.show()
